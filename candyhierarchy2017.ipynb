# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('candyhierarchy2017.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
df.shape
# Out:
# (2460, 120)

# %%
df.set_index('Internal ID', inplace = True)

# %%
df['Unnamed: 113'].value_counts(dropna = False)
# Out:
# NaN                                                                        2451
# dress (https://survey.ubc.ca/media/assets/user/14372/storage/dress.png)       9
# Name: Unnamed: 113, dtype: int64

# %%
## The columns 'Q5: STATE, PROVINCE, COUNTY, ETC', 'Q7: JOY OTHER', 'Q8: DESPAIR OTHER', 'Q9: OTHER COMMENTS', 'Unnamed: 113', and 'Click Coordinates (x, y)' have many missing values and are not useful, hence they will be dropped.
to_drop = ['Q5: STATE, PROVINCE, COUNTY, ETC', 'Q7: JOY OTHER', 'Q8: DESPAIR OTHER', 
           'Q9: OTHER COMMENTS', 'Unnamed: 113', 'Click Coordinates (x, y)']
df.drop(to_drop, inplace = True, axis = 1)

# %%
df.dtypes
# Out:
# Q1: GOING OUT?                                                                             object
# Q2: GENDER                                                                                 object
# Q3: AGE                                                                                    object
# Q4: COUNTRY                                                                                object
# Q6 | 100 Grand Bar                                                                         object
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     object
# Q6 | Any full-sized candy bar                                                              object
# Q6 | Black Jacks                                                                           object
# Q6 | Bonkers (the candy)                                                                   object
# Q6 | Bonkers (the board game)                                                              object
# ...

# %%
for col in df:
    if df[col].dtypes == 'float64':
        df[col] = df[col].fillna('0')

# %%
df.head()
# Out:
#             Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY Q6 | 100 Grand Bar  \
# Internal ID
# 90258773               NaN        NaN     NaN         NaN                NaN
# 90272821                No       Male      44        USA                 MEH
# 90272829               NaN       Male      49         USA                NaN
# 90272840                No       Male      40          us                MEH
# 90272841                No       Male      23         usa                JOY
#
#             Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90258773                                                   NaN
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# 90272841                                               DESPAIR
#
# ...

# %%
candies = df.iloc[:, 6:-10]
candies.describe()
# Out:
#        Q6 | Any full-sized candy bar Q6 | Black Jacks  \
# count                           1788             1502
# unique                             3                3
# top                              JOY          DESPAIR
# freq                            1559              793
#
#        Q6 | Bonkers (the candy) Q6 | Bonkers (the board game)  \
# count                      1468                          1454
# unique                        3                             3
# top                         MEH                           MEH
# freq                        857                           715
#
#        Q6 | Bottle Caps Q6 | Box'o'Raisins Q6 | Broken glow stick  \
# count              1695               1772                   1754
# unique                3                  3                      3
# top                 MEH            DESPAIR                DESPAIR
# freq                670               1179                   1625
#
# ...

# %%
df['Q4: COUNTRY'].unique()
# Out:
# array([nan, 'USA ', 'USA', 'us', 'usa', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'United States', 'uk', 'United Kingdom', 'united states',
#        'Usa', 'United States ', 'United staes',
#        'United States of America', 'UAE', 'England', 'UK', 'canada ',
#        'Mexico', 'United states', 'u.s.a.', 'USAUSAUSA', 'america', '35',
#        'france', 'United States of America ', 'U.S.A.', 'finland',
#        'unhinged states', 'Canada ', 'united states of america',
#        'US of A', 'Unites States', 'The United States', 'North Carolina ',
#        'Unied States', 'Netherlands', 'germany', 'Europe', 'Earth', 'U S',
#        'u.s.', 'U.K. ', 'Costa Rica', 'The United States of America',
#        'unite states', 'U.S.', '46', 'cascadia', 'Australia',
#        'insanity lately', 'Greece', 'USA? Hard to tell anymore..',
#        "'merica", 'usas', 'Pittsburgh', '45', 'United State', '32',
#        'France', 'australia', 'A', 'Can', 'Canae', 'New York',
# ...

# %%
df.replace(['murrika', 'Murica', 'A', 'USAA', 'USA ', 'us', 'USA', 'US', 'Us', 'usa', 'united states', 
            'united states of america', 'Usa', 'United States ', 'United staes','United States of America',
            'United states','u.s.a.','USAUSAUSA', 'america', 'United States of America ','U.S.A.', 'unhinged states',
            'united states of america', 'US of A', 'Unites States', 'The United States', 'North Carolina ','Unied States',
            'U S', 'u.s.', 'The United States of America', 'unite states', 'U.S.', 'cascadia', 'USA? Hard to tell anymore..', "'merica", 'usas', 'Pittsburgh', 
            'United State', 'New York', 'Trumpistan', 'United Sates', 'California', 'USa',
            'I pretend to be from Canada, but I am really from the United States.', 'Usa ', 'United Stated',
            'Ahem....Amerca', 'UD', 'New Jersey', 'United ststes', 'America', 'United Statss', 'USA! USA! USA!',
            'Alaska', 'united States ', 'N. America', 'USSA', 'U.S. ', 'u s a', 'United Statea', 'united ststes', 
            'USA USA USA!!!!'], "United States", inplace = True)
df.replace(['Soviet Canuckistan','Soviet canuckistan', 'canada', 'Canada', 'canada ', 'Canada ', 'Can', 'Canae', 'Canada`',
            'CANADA'], "Canada", inplace = True)
df.replace(['United kingdom', 'uk', 'United Kingdom', 'UK', 'U.K. ', 'Uk', 'UK ', 'Scotland ', 'England'], "United Kingdom",
           inplace = True)
df.replace(['finland'], 'Finland', inplace = True)
df.replace(['france', 'France', 'France '], 'France', inplace = True)
df.replace(['The Netherlands', 'Netherlands'], 'Netherlands', inplace = True)
df.replace(['Ireland ', 'Ireland'], 'Ireland', inplace = True)
df.replace(['Uae'], 'United Arab Emirates', inplace = True)
df.replace(['35', 'Europe', 'Earth', '46', 'insanity lately', '45', '32', 'endland', 'Atlantis', 'Narnia', '1', 
            'subscribe to dm4uz3 on youtube',  "I don't know anymore", 'Fear and Loathing'], np.nan, inplace = True)
df['Q4: COUNTRY'] = df['Q4: COUNTRY'].str.title()

# %%
df['Q4: COUNTRY'].unique()
# Out:
# array([nan, 'United States', 'Canada', 'United Kingdom', 'Uae', 'Mexico',
#        'France', 'Finland', 'Netherlands', 'Germany', 'Costa Rica',
#        'Australia', 'Greece', 'Ireland', 'Korea', 'Japan', 'South Africa',
#        'Iceland', 'Scotland', 'Denmark', 'Switzerland', 'South Korea',
#        'Indonesia', 'Soviet Canuckistan', 'Singapore', 'China', 'Taiwan',
#        'Hong Kong', 'Spain', 'Sweden'], dtype=object)

# %%
df['Q2: GENDER'].unique()
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
df.replace(["I'd rather not say", 'Other'], np.nan, inplace = True)

# %%
df['Q3: AGE'].unique()
# Out:
# array([nan, '44', '49', '40', '23', '53', '33', '43', '56', '64', '37',
#        '59', '48', '54', '36', '25', '34', '38', '58', '50', '47', '16',
#        '52', '63', '65', '41', '27', '31', '61', '42', '62', '29', '39',
#        '28', '69', '67', '30', '22', '26', '51', '70', '24', '18', '19',
#        'Old enough', '57', '60', '66', '12', 'Many', '55', '72', '?',
#        '21', '11', 'no', '9', '68', '20', '6', '10', '71', '90', '13',
#        '45-55', '312', '99', '7', 'hahahahaha', '88', '39.4', '74', '102',
#        'older than dirt', '17', '15', '8', '75', '5u', 'Enough',
#        'See question 2', '24-50', '14', 'Over 50', '100', '76', '1000',
#        'sixty-nine', '46 Halloweens.', 'ancient', '77', 'OLD', 'old',
#        '73', '70 1/2', 'MY NAME JEFF', '4',
#        '59 on the day after Halloween', 'old enough', 'your mom',
#        'I can remember when Java was a cool new language', '60+'],
#       dtype=object)

# %%
# Unexpected missing values will be removed.
df['Q3: AGE'] = df['Q3: AGE'].apply(pd.to_numeric, errors = 'coerce')

# %%
df['Q3: AGE'].unique()
# Out:
# array([   nan,   44. ,   49. ,   40. ,   23. ,   53. ,   33. ,   43. ,
#          56. ,   64. ,   37. ,   59. ,   48. ,   54. ,   36. ,   25. ,
#          34. ,   38. ,   58. ,   50. ,   47. ,   16. ,   52. ,   63. ,
#          65. ,   41. ,   27. ,   31. ,   61. ,   42. ,   62. ,   29. ,
#          39. ,   28. ,   69. ,   67. ,   30. ,   22. ,   26. ,   51. ,
#          70. ,   24. ,   18. ,   19. ,   57. ,   60. ,   66. ,   12. ,
#          55. ,   72. ,   21. ,   11. ,    9. ,   68. ,   20. ,    6. ,
#          10. ,   71. ,   90. ,   13. ,  312. ,   99. ,    7. ,   88. ,
#          39.4,   74. ,  102. ,   17. ,   15. ,    8. ,   75. ,   14. ,
#         100. ,   76. , 1000. ,   77. ,   73. ,    4. ])

# %%
df.head()
# Out:
#             Q1: GOING OUT? Q2: GENDER  Q3: AGE    Q4: COUNTRY  \
# Internal ID
# 90258773               NaN        NaN      NaN            NaN
# 90272821                No       Male     44.0  United States
# 90272829               NaN       Male     49.0  United States
# 90272840                No       Male     40.0  United States
# 90272841                No       Male     23.0  United States
#
#             Q6 | 100 Grand Bar  \
# Internal ID
# 90258773                   NaN
# 90272821                   MEH
# 90272829                   NaN
# 90272840                   MEH
# 90272841                   JOY
#
#             Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Internal ID
# 90258773                                                   NaN
# 90272821                                               DESPAIR
# 90272829                                                   NaN
# 90272840                                               DESPAIR
# ...
