# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('MetObjects.csv', low_memory = False)

# %%
df.head()
# Out:
#   Object Number  Is Highlight  Is Public Domain  Object ID         Department  \
# 0    1979.486.1         False             False          1  The American Wing
# 1    1980.264.5         False             False          2  The American Wing
# 2      67.265.9         False             False          3  The American Wing
# 3     67.265.10         False             False          4  The American Wing
# 4     67.265.11         False             False          5  The American Wing
#
#   Object Name                         Title Culture Period Dynasty  ...  \
# 0        Coin  One-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 1        Coin  Ten-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 2        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 3        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 4        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
#
# ...

# %%
df.shape
df.info()
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473934 entries, 0 to 473933
# Data columns (total 44 columns):
# Object Number              473934 non-null object
# Is Highlight               473934 non-null bool
# Is Public Domain           473934 non-null bool
# Object ID                  473934 non-null int64
# Department                 473934 non-null object
# Object Name                472020 non-null object
# Title                      443972 non-null object
# Culture                    206214 non-null object
# Period                     88761 non-null object
# Dynasty                    23133 non-null object
# Reign                      11160 non-null object
# Portfolio                  23036 non-null object
# Artist Role                269871 non-null object
# Artist Prefix              89025 non-null object
# Artist Display Name        271965 non-null object
# Artist Display Bio         232633 non-null object
# Artist Suffix              11970 non-null object
# ...

# %%
df = df.dropna(axis = 1, thresh=45000)

# %%
df.columns
# Out:
# Index(['Object Number', 'Is Highlight', 'Is Public Domain', 'Object ID',
#        'Department', 'Object Name', 'Title', 'Culture', 'Period',
#        'Artist Role', 'Artist Prefix', 'Artist Display Name',
#        'Artist Display Bio', 'Artist Alpha Sort', 'Artist Nationality',
#        'Artist Begin Date', 'Artist End Date', 'Object Date',
#        'Object Begin Date', 'Object End Date', 'Medium', 'Dimensions',
#        'Credit Line', 'Geography Type', 'Country', 'Classification',
#        'Link Resource', 'Metadata Date', 'Repository', 'Tags'],
#       dtype='object')

# %%
df.shape
# Out:
# (473934, 30)

# %%
df.isnull().sum()
# Out:
# Object Number               0
# Is Highlight                0
# Is Public Domain            0
# Object ID                   0
# Department                  0
# Object Name              1914
# Title                   29962
# Culture                267720
# Period                 385173
# Artist Role            204063
# Artist Prefix          384909
# Artist Display Name    201969
# Artist Display Bio     241301
# Artist Alpha Sort      202003
# Artist Nationality     291437
# Artist Begin Date      238695
# Artist End Date        240979
# Object Date             14928
# Object Begin Date           0
# Object End Date             0
# Medium                   7170
# Dimensions              75571
# Credit Line               495
# Geography Type         414795
# Country                398827
# Classification          55999
# Link Resource               0
# Metadata Date          109423
# Repository                  0
# Tags                   253474
# dtype: int64

# %%
df.set_index('Object ID', inplace = True)

# %%
df.head()
# Out:
#           Object Number  Is Highlight  Is Public Domain         Department  \
# Object ID
# 1            1979.486.1         False             False  The American Wing
# 2            1980.264.5         False             False  The American Wing
# 3              67.265.9         False             False  The American Wing
# 4             67.265.10         False             False  The American Wing
# 5             67.265.11         False             False  The American Wing
#
#           Object Name                         Title Culture Period  \
# Object ID
# 1                Coin  One-dollar Liberty Head Coin     NaN    NaN
# 2                Coin  Ten-dollar Liberty Head Coin     NaN    NaN
# 3                Coin    Two-and-a-Half Dollar Coin     NaN    NaN
# 4                Coin    Two-and-a-Half Dollar Coin     NaN    NaN
# 5                Coin    Two-and-a-Half Dollar Coin     NaN    NaN
#
#           Artist Role Artist Prefix  ... Medium                Dimensions  \
# ...

# %%
df['Artist Role'].unique()
# Out:
# array(['Maker', nan, 'Artist', ..., 'Subject|Lithographer|Artist',
#        'Author|Publisher|Translator|Engraver|Engraver|Engraver|Engraver|Engraver|Engraver',
#        'Draftsman|Author|Publisher'], dtype=object)

# %%
to_drop = ['Link Resource', 'Repository', 'Object Number']
df.drop(to_drop, axis = 1, inplace = True)

# %%
df.head()
# Out:
#            Is Highlight  Is Public Domain         Department Object Name  \
# Object ID
# 1                 False             False  The American Wing        Coin
# 2                 False             False  The American Wing        Coin
# 3                 False             False  The American Wing        Coin
# 4                 False             False  The American Wing        Coin
# 5                 False             False  The American Wing        Coin
#
#                                   Title Culture Period Artist Role  \
# Object ID
# 1          One-dollar Liberty Head Coin     NaN    NaN       Maker
# 2          Ten-dollar Liberty Head Coin     NaN    NaN       Maker
# 3            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
# 4            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
# 5            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
#
#           Artist Prefix    Artist Display Name  ... Object Begin Date  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Is Highlight', 'Is Public Domain', 'Department', 'Object Name',
#        'Title', 'Culture', 'Period', 'Artist Role', 'Artist Prefix',
#        'Artist Display Name', 'Artist Display Bio', 'Artist Alpha Sort',
#        'Artist Nationality', 'Artist Begin Date', 'Artist End Date',
#        'Object Date', 'Object Begin Date', 'Object End Date', 'Medium',
#        'Dimensions', 'Credit Line', 'Geography Type', 'Country',
#        'Classification', 'Metadata Date', 'Tags'],
#       dtype='object')

# %%
type(df.iloc[0, 13])
# Out:
# str

# %%
df['Artist Begin Date']
# Out:
# Object ID
# 1         1794
# 2         1785
# 3          nan
# 4          nan
# 5          nan
# 6          nan
# 7          nan
# 8          nan
# 9          nan
# 10        1867
# 11        1785
# 12        1794
# 13        1867
# 14        1785
# 15         nan
# 16         nan
# 17         nan
# 18         nan
# 19         nan
# 20         nan
# 21         nan
# 22         nan
# 23         nan
# 24         nan
# 25         nan
# 26         nan
# 27         nan
# 28         nan
# 29         nan
# 30         nan
#           ...
# 843487    1412
# 843488    1893
# 843489    1862
# 843490    1893
# 843493    1893
# 843495    1893
# 843502    1893
# 843506    1893
# 843508    1893
# 843510    1893
# 843511    1893
# 843512    1862
# 843513    1893
# 843514    1862
# 843515    1862
# 843516    1893
# 843517    1893
# 843518    1893
# 843520    1723
# 843524    1862
# 843526    1818
# 843528    1769
# 843530    1723
# 843536    1734
# 843554    1862
# 843558    1758
# 843560    1742
# ...

# %%
df['Artist End Date'] = df['Artist End Date'].astype(str).str[:4]

# %%
df.head()
# Out:
#            Is Highlight  Is Public Domain         Department Object Name  \
# Object ID
# 1                 False             False  The American Wing        Coin
# 2                 False             False  The American Wing        Coin
# 3                 False             False  The American Wing        Coin
# 4                 False             False  The American Wing        Coin
# 5                 False             False  The American Wing        Coin
#
#                                   Title Culture Period Artist Role  \
# Object ID
# 1          One-dollar Liberty Head Coin     NaN    NaN       Maker
# 2          Ten-dollar Liberty Head Coin     NaN    NaN       Maker
# 3            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
# 4            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
# 5            Two-and-a-Half Dollar Coin     NaN    NaN         NaN
#
#           Artist Prefix    Artist Display Name  ... Object Begin Date  \
# ...
